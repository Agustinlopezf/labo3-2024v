# %%
import pandas as pd
import os
import numpy as np

entorno = 'local'  # Elegir "VM" o "local" para correr en entorno local
nombre_experimento = 'LSTM_producto'
ventana_input = 12
ventana_output = 2
ventana_test = 3
lags = [1, 2, 3, 6, 12]


# Configurar entorno
if entorno == 'VM':
    carpeta_datasets = '~/buckets/b1/datasets'
    carpeta_exp_base = '~/buckets/b1/exp'
elif entorno == 'local':
    carpeta_datasets = 'C:\\Users\\alope\\Desktop\\Trámites\\Maestria Data Science - Universidad Austral\\Laboratorio de implementación 3\\Datos'
    carpeta_exp_base = 'C:\\Users\\alope\\Desktop\\Trámites\\Maestria Data Science - Universidad Austral\\Laboratorio de implementación 3\\Resultados'
else:
    raise Exception("Entorno especificado incorrectamente")

carpeta_exp = os.path.join(carpeta_exp_base, nombre_experimento)
if not os.path.exists(carpeta_exp):
    os.makedirs(carpeta_exp)

# %%
# Cargar datos
sell_in = pd.read_csv(os.path.join(carpeta_datasets, 'sell-in.txt'), delimiter='\t')
tb_productos = pd.read_csv(os.path.join(carpeta_datasets, 'tb_productos_descripcion.txt'), delimiter='\t')
tb_stocks = pd.read_csv(os.path.join(carpeta_datasets, 'tb_stocks.txt'), delimiter='\t')
productos_predecir = pd.read_csv(os.path.join(carpeta_datasets, 'productos_a_predecir.txt'), delimiter='\t')

# %%
ventas_producto_mes = sell_in.groupby(['periodo', 'product_id'])['tn'].sum()
ventas_producto_mes = ventas_producto_mes.reset_index()
ventas_producto_mes['Timestamp'] = pd.to_datetime(ventas_producto_mes['periodo'], format='%Y%m')
ventas_producto_mes.set_index('Timestamp', inplace=True)
ventas_producto_mes.drop(columns=['periodo'], inplace = True)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import StandardScaler


def crear_dataset_supervisado(array, input_length, output_length):
    # Inicialización
    X, Y = [], []    # Listados que contendrán los datos de entrada y salida del modelo
    shape = array.shape
    if len(shape) == 1:  # Si tenemos sólo una serie (univariado)
        array = array.reshape(-1, 1)
        cols = 1
    else:  # Multivariado
        fils, cols = array.shape

    # Generar los arreglos (utilizando ventanas deslizantes de longitud input_length)
    for i in range(fils - input_length - output_length + 1):
        X.append(array[i:i + input_length, :].reshape(input_length, cols))
        Y.append(array[i + input_length:i + input_length + output_length, -1].reshape(output_length, 1))

    # Convertir listas a arreglos de NumPy
    X = np.array(X)
    Y = np.array(Y)

    return X, Y

def predecir(x, model, scaler):
    # Calcular predicción escalada en el rango de escalado
    y_pred_s = model.predict(x,verbose=0)
    # Llevar la predicción a la escala original
    y_pred = scaler.inverse_transform(y_pred_s)
    return y_pred.flatten()

def agregar_lags(df, lags):
    for lag in lags:
        df[f'lag_{lag}'] = df['tn'].shift(lag)
    df.bfill(inplace=True)  # Usar backfill para llenar los valores NaN
    return df



lista_productos_LSTM = []
lista_predicciones_LSTM = []
scaler_list = []

for producto in ventas_producto_mes['product_id'].unique():
    if producto in list(productos_predecir['product_id']):
        print(f'Entrenando producto {producto}',  end="\r")
        ventas_mes_por_producto = ventas_producto_mes[ventas_producto_mes['product_id'] == producto].copy()
        #print(f'Tiene {len(ventas_mes_por_producto)} ejemplos de entrenamiento')
        ventas_mes_por_producto.drop(columns=['product_id'], inplace = True)

        #Escalar valor
        scaler = StandardScaler()
        ventas_mes_por_producto['tn'] = scaler.fit_transform(ventas_mes_por_producto)
        scaler_list.append(scaler)
        
        # Agregar lags a los datos escalados y eliminar la columna original
        ventas_mes_por_producto = agregar_lags(ventas_mes_por_producto, lags)
        
        if len(ventas_mes_por_producto) >= (ventana_input + ventana_output):
            #Formatear valores para input LSTM
            X, Y =crear_dataset_supervisado(ventas_mes_por_producto.values, ventana_input, ventana_output)

            # Create and fit the LSTM network
            model = Sequential()
            model.add(LSTM(128, return_sequences=True, input_shape=(ventana_input, X.shape[2]), recurrent_dropout=0.25))
            model.add(LSTM(64,return_sequences = True, recurrent_dropout=0.25))
            model.add(LSTM(32, recurrent_dropout=0.25))
            model.add(Dropout(0.5))
            model.add(Dense(ventana_output))
            model.compile(loss='mean_squared_error', optimizer='adam')
            model.fit(X, Y, epochs=100, batch_size=1, verbose=0)

            #Predecir valores
            input_prediccion = X[-1].reshape(1,X.shape[1],X.shape[2])
            prediccion_mes_2 = predecir(input_prediccion, model, scaler)[1]

            lista_productos_LSTM.append(producto)
            lista_predicciones_LSTM.append(prediccion_mes_2)
        else:
            print('Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio')
            lista_productos_LSTM.append(producto)
            lista_predicciones_LSTM.append(ventas_mes_por_producto['tn'].mean())
# Out:
# Entrenando producto 20001
# Entrenando producto 20002
# Entrenando producto 20003
# Entrenando producto 20004
# Entrenando producto 20005
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000184FFCE37E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Entrenando producto 20006
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000184F2CE8EA0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Entrenando producto 20007
# Entrenando producto 20008
# Entrenando producto 20009
# Entrenando producto 20010
# Entrenando producto 20011
# Entrenando producto 20012
# Entrenando producto 20013
# Entrenando producto 20014
# Entrenando producto 20015
# Entrenando producto 20016
# Entrenando producto 20017
# Entrenando producto 20018
# Entrenando producto 20019
# Entrenando producto 20020
# Entrenando producto 20021
# Entrenando producto 20022
# Entrenando producto 20023
# Entrenando producto 20024
# Entrenando producto 20025
# Entrenando producto 20026
# Entrenando producto 20027
# Entrenando producto 20028
# Entrenando producto 20029
# Entrenando producto 20030
# Entrenando producto 20031
# Entrenando producto 20033
# Entrenando producto 20035
# Entrenando producto 20037
# Entrenando producto 20038
# Entrenando producto 20039
# Entrenando producto 20041
# Entrenando producto 20042
# Entrenando producto 20043
# Entrenando producto 20044
# Entrenando producto 20045
# Entrenando producto 20046
# Entrenando producto 20047
# Entrenando producto 20050
# Entrenando producto 20051
# Entrenando producto 20052
# Entrenando producto 20053
# Entrenando producto 20054
# Entrenando producto 20055
# Entrenando producto 20056
# Entrenando producto 20057
# Entrenando producto 20058
# Entrenando producto 20059
# Entrenando producto 20061
# Entrenando producto 20062
# Entrenando producto 20063
# Entrenando producto 20065
# Entrenando producto 20066
# Entrenando producto 20067
# Entrenando producto 20068
# Entrenando producto 20069
# Entrenando producto 20070
# Entrenando producto 20263
# Entrenando producto 20264
# Entrenando producto 20265
# Entrenando producto 20267
# Entrenando producto 20268
# Entrenando producto 20269
# Entrenando producto 20270
# Entrenando producto 20271
# Entrenando producto 20272
# Entrenando producto 20273
# Entrenando producto 20275
# Entrenando producto 20276
# Entrenando producto 20277
# Entrenando producto 20278
# Entrenando producto 20280
# Entrenando producto 20281
# Entrenando producto 20282
# Entrenando producto 20283
# Entrenando producto 20284
# Entrenando producto 20285
# Entrenando producto 20288
# Entrenando producto 20289
# Entrenando producto 20290
# Entrenando producto 20291
# Entrenando producto 20292
# Entrenando producto 20295
# Entrenando producto 20296
# Entrenando producto 20299
# Entrenando producto 20300
# Entrenando producto 20301
# Entrenando producto 20302
# Entrenando producto 20303
# Entrenando producto 20304
# Entrenando producto 20305
# Entrenando producto 20307
# Entrenando producto 20309
# Entrenando producto 20310
# Entrenando producto 20311
# Entrenando producto 20313
# Entrenando producto 20314
# Entrenando producto 20315
# Entrenando producto 20316
# Entrenando producto 20317
# Entrenando producto 20320
# Entrenando producto 20321
# Entrenando producto 20322
# Entrenando producto 20324
# Entrenando producto 20325
# Entrenando producto 20326
# Entrenando producto 20327
# Entrenando producto 20328
# Entrenando producto 20329
# Entrenando producto 20330
# Entrenando producto 20332
# Entrenando producto 20335
# Entrenando producto 20336
# Entrenando producto 20338
# Entrenando producto 20341
# Entrenando producto 20342
# Entrenando producto 20346
# Entrenando producto 20349
# Entrenando producto 20350
# Entrenando producto 20352
# Entrenando producto 20353
# Entrenando producto 20354
# Entrenando producto 20356
# Entrenando producto 20357
# Entrenando producto 20358
# Entrenando producto 20359
# Entrenando producto 20361
# Entrenando producto 20362
# Entrenando producto 20365
# Entrenando producto 20366
# Entrenando producto 20367
# Entrenando producto 20372
# Entrenando producto 20375
# Entrenando producto 20379
# Entrenando producto 20380
# Entrenando producto 20381
# Entrenando producto 20382
# Entrenando producto 20383
# Entrenando producto 20384
# Entrenando producto 20385
# Entrenando producto 20386
# Entrenando producto 20388
# Entrenando producto 20396
# Entrenando producto 20398
# Entrenando producto 20400
# Entrenando producto 20401
# Entrenando producto 20404
# Entrenando producto 20406
# Entrenando producto 20407
# Entrenando producto 20409
# Entrenando producto 20410
# Entrenando producto 20411
# Entrenando producto 20416
# Entrenando producto 20418
# Entrenando producto 20419
# Entrenando producto 20421
# Entrenando producto 20422
# Entrenando producto 20424
# Entrenando producto 20426
# Entrenando producto 20428
# Entrenando producto 20429
# Entrenando producto 20432
# Entrenando producto 20433
# Entrenando producto 20434
# Entrenando producto 20438
# Entrenando producto 20443
# Entrenando producto 20449
# Entrenando producto 20450
# Entrenando producto 20456
# Entrenando producto 20463
# Entrenando producto 20464
# Entrenando producto 20465
# Entrenando producto 20466
# Entrenando producto 20469
# Entrenando producto 20470
# Entrenando producto 20473
# Entrenando producto 20474
# Entrenando producto 20480
# Entrenando producto 20482
# Entrenando producto 20483
# Entrenando producto 20484
# Entrenando producto 20490
# Entrenando producto 20497
# Entrenando producto 20500
# Entrenando producto 20502
# Entrenando producto 20505
# Entrenando producto 20509
# Entrenando producto 20517
# Entrenando producto 20520
# Entrenando producto 20524
# Entrenando producto 20530
# Entrenando producto 20532
# Entrenando producto 20536
# Entrenando producto 20538
# Entrenando producto 20539
# Entrenando producto 20549
# Entrenando producto 20551
# Entrenando producto 20555
# Entrenando producto 20560
# Entrenando producto 20561
# Entrenando producto 20563
# Entrenando producto 20565
# Entrenando producto 20568
# Entrenando producto 20570
# Entrenando producto 20572
# Entrenando producto 20579
# Entrenando producto 20583
# Entrenando producto 20585
# Entrenando producto 20586
# Entrenando producto 20596
# Entrenando producto 20597
# Entrenando producto 20599
# Entrenando producto 20600
# Entrenando producto 20601
# Entrenando producto 20602
# Entrenando producto 20605
# Entrenando producto 20606
# Entrenando producto 20609
# Entrenando producto 20612
# Entrenando producto 20614
# Entrenando producto 20617
# Entrenando producto 20622
# Entrenando producto 20628
# Entrenando producto 20629
# Entrenando producto 20632
# Entrenando producto 20636
# Entrenando producto 20637
# Entrenando producto 20639
# Entrenando producto 20640
# Entrenando producto 20641
# Entrenando producto 20642
# Entrenando producto 20644
# Entrenando producto 20647
# Entrenando producto 20651
# Entrenando producto 20652
# Entrenando producto 20653
# Entrenando producto 20654
# Entrenando producto 20655
# Entrenando producto 20658
# Entrenando producto 20660
# Entrenando producto 20661
# Entrenando producto 20663
# Entrenando producto 20664
# Entrenando producto 20666
# Entrenando producto 20670
# Entrenando producto 20672
# Entrenando producto 20676
# Entrenando producto 20677
# Entrenando producto 20678
# Entrenando producto 20680
# Entrenando producto 20684
# Entrenando producto 20685
# Entrenando producto 20693
# Entrenando producto 20696
# Entrenando producto 20697
# Entrenando producto 20699
# Entrenando producto 20701
# Entrenando producto 20702
# Entrenando producto 20705
# Entrenando producto 20706
# Entrenando producto 20708
# Entrenando producto 20713
# Entrenando producto 20714
# Entrenando producto 20715
# Entrenando producto 20721
# Entrenando producto 20729
# Entrenando producto 20730
# Entrenando producto 20733
# Entrenando producto 20735
# Entrenando producto 20737
# Entrenando producto 20739
# Entrenando producto 20742
# Entrenando producto 20744
# Entrenando producto 20745
# Entrenando producto 20749
# Entrenando producto 20751
# Entrenando producto 20756
# Entrenando producto 20759
# Entrenando producto 20761
# Entrenando producto 20765
# Entrenando producto 20768
# Entrenando producto 20773
# Entrenando producto 20781
# Entrenando producto 20786
# Entrenando producto 20788
# Entrenando producto 20789
# Entrenando producto 20793
# Entrenando producto 20800
# Entrenando producto 20801
# Entrenando producto 20802
# Entrenando producto 20803
# Entrenando producto 20807
# Entrenando producto 20810
# Entrenando producto 20812
# Entrenando producto 20820
# Entrenando producto 20823
# Entrenando producto 20824
# Entrenando producto 20826
# Entrenando producto 20828
# Entrenando producto 20830
# Entrenando producto 20831
# Entrenando producto 20838
# Entrenando producto 20840
# Entrenando producto 20843
# Entrenando producto 20846
# Entrenando producto 20847
# Entrenando producto 20849
# Entrenando producto 20852
valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20575
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20577
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20593
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20603
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20633
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20681
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20719
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20746
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20785
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20795
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20822
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20859
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20907
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20920
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20966
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20987
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21086
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21092
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21179
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21196
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20754
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20924
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20928
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20932
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20946
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21042
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21044
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21064
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21074
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21099
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21135
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21163
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21171
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20174
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20592
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20649
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20674
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20691
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20732
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20772
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20774
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20827
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20927
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21007
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21111
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21114
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21119
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21140
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21227
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20236
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20261
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20440
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20615
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20621
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20662
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20673
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20711
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20720
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20845
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20886
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20904
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20910
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20912
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20933
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20953
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21006
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21035
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21039
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21079
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21109
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21112
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20213
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20257
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20694
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20762
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20815
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20899
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20942
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20968
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21058
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21097
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21110
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21129
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21144
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21146
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21154
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20127
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20210
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20686
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20703
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20962
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20975
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 20995
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21087
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Entrenando producto 21214
# Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio

# %%
resultados_kaggle_LSTM = pd.DataFrame({'product_id': lista_productos_LSTM, 'tn': lista_predicciones_LSTM})
resultados_kaggle_LSTM['tn'] = resultados_kaggle_LSTM['tn'].apply(lambda x: max(0,x))
resultados_kaggle_LSTM.to_csv(os.path.join(carpeta_exp, 'predicciones_LSTM_droput.csv'), index= False)

# %%
import pandas as pd
import os
import numpy as np
import optuna
import logging
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import RobustScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import MeanSquaredError
import json

entorno = 'local'  # Elegir "VM" o "local" para correr en entorno local
nombre_experimento = 'LSTM_producto_modelo_final_optuna'
nombre_carpeta_optuna = 'LSTM_producto_optuna'
ventana_input = 12
ventana_output = 2




# Configurar entorno
if entorno == 'VM':
    carpeta_datasets = os.path.expanduser('~/buckets/b1/datasets')
    carpeta_exp_base = os.path.expanduser('~/buckets/b1/exp')
elif entorno == 'local':
    carpeta_datasets = 'C:\\Users\\alope\\Desktop\\Trámites\\Maestria Data Science - Universidad Austral\\Laboratorio de implementación 3\\Datos'
    carpeta_exp_base = 'C:\\Users\\alope\\Desktop\\Trámites\\Maestria Data Science - Universidad Austral\\Laboratorio de implementación 3\\Resultados'
else:
    raise Exception("Entorno especificado incorrectamente")

carpeta_exp = os.path.join(carpeta_exp_base, nombre_experimento)
if not os.path.exists(carpeta_exp):
    os.makedirs(carpeta_exp)


dataset_completo = pd.read_csv(os.path.join(carpeta_datasets, 'df_producto_cliente_completo.csv'))


dataset_completo.head()
# Out:
#     Timestamp  customer_id  product_id  plan_precios_cuidados
# 0  2017-01-01        10234       20524                    0.0  \
# 1  2017-02-01        10234       20524                    NaN
# 2  2017-03-01        10234       20524                    0.0
# 3  2017-04-01        10234       20524                    NaN
# 4  2017-05-01        10234       20524                    NaN
#
#    cust_request_qty  cust_request_tn       tn cat1     cat2        cat3  ...
# 0               2.0          0.05300  0.05300   HC  VAJILLA  Cristalino  ...  \
# 1               0.0          0.00000  0.00000   HC  VAJILLA  Cristalino  ...
# 2               1.0          0.01514  0.01514   HC  VAJILLA  Cristalino  ...
# 3               0.0          0.00000  0.00000   HC  VAJILLA  Cristalino  ...
# 4               0.0          0.00000  0.00000   HC  VAJILLA  Cristalino  ...
#
#   sku_size    descripcion mes  quarter  fin_quarter  edad_producto
# 0    500.0  Abrillantador   1        1            0              0  \
# 1    500.0  Abrillantador   2        1            0              1
# 2    500.0  Abrillantador   3        1            1              2
# 3    500.0  Abrillantador   4        2            0              3
# 4    500.0  Abrillantador   5        2            0              4
#
#    ventas_cat1  ventas_cat2  ventas_cat3  ventas_familia_producto
# 0     14.31686      4.96628      3.03194                  0.25684
# 1      2.14290      0.10339      0.00000                  0.00000
# 2      8.59237      2.23835      1.52777                  0.04699
# 3      9.18260      4.47157      2.35257                  0.00000
# 4      7.79714      0.50130      0.09348                  0.00000
#
# [5 rows x 21 columns]

# %%
#Recuperar mejores hiperparametros de optimizacion
with open(os.path.join(os.path.join(carpeta_exp_base,nombre_carpeta_optuna), 'mejores_hiperparametros.json'), 'r') as f:
    best_params = json.load(f)
print(best_params)

units_lstm = [best_params['units_lstm_1'], best_params['units_lstm_2'], best_params['units_lstm_3']]
dropout_rate = best_params['dropout_rate']
learning_rate = best_params['learning_rate']
batch_size = best_params['batch_size']
epochs = best_params['epochs']
# Out:
# {'units_lstm_1': 59, 'units_lstm_2': 73, 'units_lstm_3': 35, 'dropout_rate': 0.41700621444181185, 'learning_rate': 0.00023448023148398307, 'batch_size': 17, 'epochs': 65}

# %%
ventas_producto_mes = dataset_completo.groupby(['Timestamp', 'product_id'])['tn'].sum()
ventas_producto_mes = ventas_producto_mes.reset_index()
ventas_producto_mes.set_index('Timestamp', inplace=True)
ventas_producto_mes
# Out:
#             product_id          tn
# Timestamp
# 2017-01-01       20001   934.77222
# 2017-01-01       20002   550.15707
# 2017-01-01       20003  1063.45835
# 2017-01-01       20004   555.91614
# 2017-01-01       20005   494.27011
# ...                ...         ...
# 2019-12-01       21263     0.01270
# 2019-12-01       21265     0.05007
# 2019-12-01       21266     0.05121
# 2019-12-01       21267     0.01569
# 2019-12-01       21276     0.00892
#
# [22375 rows x 2 columns]

# %%
def crear_dataset_supervisado(array, input_length, output_length):
    # Inicialización
    X, Y = [], []    # Listados que contendrán los datos de entrada y salida del modelo
    shape = array.shape
    if len(shape) == 1:  # Si tenemos sólo una serie (univariado)
        array = array.reshape(-1, 1)
        cols = 1
    else:  # Multivariado
        fils, cols = array.shape

    # Generar los arreglos (utilizando ventanas deslizantes de longitud input_length)
    for i in range(fils - input_length - output_length + 1):
        X.append(array[i:i + input_length, :].reshape(input_length, cols))
        Y.append(array[i + input_length:i + input_length + output_length, -1].reshape(output_length, 1))

    # Convertir listas a arreglos de NumPy
    X = np.array(X)
    Y = np.array(Y)

    return X, Y

# %%
# Función para crear el modelo LSTM
def crear_modelo_lstm(input_shape, units_lstm, dropout_rate, learning_rate):
    model = Sequential()
    model.add(LSTM(units_lstm[0], return_sequences=True, input_shape=input_shape, recurrent_dropout=0.25))
    model.add(LSTM(units_lstm[1], return_sequences=True, recurrent_dropout=0.25))
    model.add(LSTM(units_lstm[2], recurrent_dropout=0.25))
    model.add(Dropout(dropout_rate))
    model.add(Dense(ventana_output))
    model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=learning_rate), metrics=[MeanSquaredError()])
    return model

def predecir(x, model, scaler):
    # Calcular predicción escalada en el rango de escalado
    y_pred_s = model.predict(x,verbose=0)
    # Llevar la predicción a la escala original
    y_pred = scaler.inverse_transform(y_pred_s)
    return y_pred.flatten()

# %%
lista_productos_LSTM = []
lista_predicciones_LSTM = []

for producto in ventas_producto_mes['product_id'].unique():
    ventas_mes_por_producto = ventas_producto_mes[ventas_producto_mes['product_id'] == producto].copy()
    ventas_mes_por_producto.drop(columns=['product_id'], inplace=True)
    
    cantidad_datos_no_nulos = len(ventas_mes_por_producto[ventas_mes_por_producto['tn'] != 0])

    if cantidad_datos_no_nulos >= (ventana_input + ventana_output):
        # Escalar valor
        scaler = RobustScaler()
        ventas_mes_por_producto['tn'] = scaler.fit_transform(ventas_mes_por_producto)
        # Formatear valores para input LSTM
        X, Y = crear_dataset_supervisado(ventas_mes_por_producto.values, ventana_input, ventana_output)

        # Crear y ajustar el modelo LSTM
        model = crear_modelo_lstm((ventana_input, X.shape[2]), units_lstm, dropout_rate, learning_rate)
        model.fit(X, Y, epochs=epochs, batch_size=batch_size, verbose=0)

        
        #Predecir valores
        input_prediccion = X[-1].reshape(1,X.shape[1],X.shape[2])
        prediccion_mes_2 = predecir(input_prediccion, model, scaler)[1]
        
        print(f'Producto {producto} - Prediccion: {prediccion_mes_2}',  end="\r")
        lista_productos_LSTM.append(producto)
        lista_predicciones_LSTM.append(prediccion_mes_2)
    else:
        print(f'Producto {producto}: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio')
        lista_productos_LSTM.append(producto)
        ventas_2019 = ventas_mes_por_producto[(ventas_mes_por_producto.index >= '2019-01-01')]
        lista_predicciones_LSTM.append(ventas_2019['tn'].mean())
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B26044AFC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001B25FC519E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Producto 20032: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21153: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21159: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21168: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20286: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20442: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20491: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20548: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20620: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20623: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20659: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20757: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21033: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21073: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21252: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21265: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21266: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21267: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21276: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20355: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20414: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20458: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20476: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20510: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20521: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20525: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20526: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20531: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20537: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20575: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20577: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20593: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20603: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20633: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20681: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20719: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20746: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20785: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20795: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20822: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20859: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20907: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20920: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20966: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20987: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21086: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21092: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21179: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21196: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20754: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20924: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20928: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20932: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20946: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21042: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21044: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21064: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21074: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21099: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21135: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21163: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21171: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20174: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20592: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20649: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20674: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20691: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20732: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20772: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20774: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20827: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20927: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21007: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21111: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21114: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21119: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21140: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21227: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20236: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20261: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20440: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20615: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20621: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20662: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20673: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20711: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20720: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20845: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20886: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20904: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20910: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20912: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20933: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20953: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21006: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21035: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21039: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21079: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21109: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21112: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20213: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20257: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20694: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20762: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20815: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20899: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20942: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20968: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21058: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21097: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21110: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21129: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21144: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21146: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21154: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20127: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20210: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20686: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20703: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20962: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20975: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 20995: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21087: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio
# Producto 21214: Valores insuficientes para usar ventana de 12 para LSTM, se predice por promedio

# %%
resultados_kaggle_LSTM = pd.DataFrame({'product_id': lista_productos_LSTM, 'tn': lista_predicciones_LSTM})
resultados_kaggle_LSTM['tn'] = resultados_kaggle_LSTM['tn'].apply(lambda x: max(0,x))
resultados_kaggle_LSTM.to_csv(os.path.join(carpeta_exp, 'predicciones_LSTM_modelo_final_optuna.csv'), index= False)

# %%
import pandas as pd
import os
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import RobustScaler, LabelEncoder
import joblib

entorno = 'VM'  # Elegir "VM" o "local" para correr en entorno local
correr_productos_mayor_ventas = True #Seleccionar True para correr solo en los productos de mas ventas del listado lista_productos_mayor_ventas
nombre_experimento = 'LSTM_producto_cliente'
nombre_archivo_log = 'log_predicciones.csv'
ventana_input = 12
ventana_output = 2
ventana_test = 3
lags = 6

lista_productos_mayor_ventas = [20001 ,20002 ,20003 ,20004 ,20005 ,20032 ,20009 ,20006 ,20011 ,20007 ,20010 ,20019 ,20013 ,20015 ,20016 ,20014 ,20024 ,20020 ,20025 ,20026]

# Configurar entorno
if entorno == 'VM':
    carpeta_datasets = os.path.expanduser('~/buckets/b1/datasets')
    carpeta_exp_base = os.path.expanduser('~/buckets/b1/exp')
elif entorno == 'local':
    carpeta_datasets = 'C:\\Users\\alope\\Desktop\\Trámites\\Maestria Data Science - Universidad Austral\\Laboratorio de implementación 3\\Datos'
    carpeta_exp_base = 'C:\\Users\\alope\\Desktop\\Trámites\\Maestria Data Science - Universidad Austral\\Laboratorio de implementación 3\\Resultados'
else:
    raise Exception("Entorno especificado incorrectamente")

carpeta_exp = os.path.join(carpeta_exp_base, nombre_experimento)
if not os.path.exists(carpeta_exp):
    os.makedirs(carpeta_exp)
    
dataset_completo = pd.read_csv(os.path.join(carpeta_datasets, 'dataset_completo.csv'))

if correr_productos_mayor_ventas:
    dataset_completo = dataset_completo[dataset_completo['product_id'].isin(lista_productos_mayor_ventas)]

#Eliminar columnas no utilizadas
dataset_completo.head()
# Out:
#       periodo  customer_id  product_id  plan_precios_cuidados
# 4145   201701        10063       20007                      0  \
# 4146   201701        10046       20007                      0
# 4147   201701        10027       20007                      0
# 4148   201701        10045       20007                      0
# 4149   201701        10488       20007                      0
#
#       cust_request_qty  cust_request_tn       tn cat1                 cat2
# 4145                 1          0.81730  0.81730   HC  ROPA ACONDICIONADOR  \
# 4146                 1          8.17296  8.17296   HC  ROPA ACONDICIONADOR
# 4147                 2          0.38919  0.38919   HC  ROPA ACONDICIONADOR
# 4148                 1          1.63460  1.63460   HC  ROPA ACONDICIONADOR
# 4149                 1          0.24324  0.24324   HC  ROPA ACONDICIONADOR
#
#                 cat3  ... sku_size  descripcion mes  quarter  fin_quarter
# 4145  ACONDICIONADOR  ...    900.0     Sabor 13   1        1            0  \
# 4146  ACONDICIONADOR  ...    900.0     Sabor 13   1        1            0
# 4147  ACONDICIONADOR  ...    900.0     Sabor 13   1        1            0
# 4148  ACONDICIONADOR  ...    900.0     Sabor 13   1        1            0
# 4149  ACONDICIONADOR  ...    900.0     Sabor 13   1        1            0
#
#       edad_producto  ventas_cat1  ventas_cat2  ventas_cat3
# 4145              0     16.71557      3.26920      3.26920  \
# 4146              0     53.07292     10.12942      9.17086
# 4147              0     40.40341      7.21172      5.35810
# 4148              0     99.03031     11.39925      9.79178
# 4149              0      2.47952      0.24324      0.24324
#
#       ventas_familia_producto
# 4145                  0.81730
# 4146                  8.17296
# 4147                  2.55135
# 4148                  4.01298
# 4149                  0.24324
#
# [5 rows x 21 columns]

# %%
#Chequear si existe log de productos con su prediccion
if os.path.exists(os.path.join(carpeta_exp, nombre_archivo_log)):
    # Si existe archivo, leerlo
    productos_con_prediccion = pd.read_csv(os.path.join(carpeta_exp,nombre_archivo_log))
else:
    #Si el archivo no existe
    productos_con_prediccion = pd.DataFrame(columns = ['product_id' , 'customer_id', 'prediccion'])


# Crear una columna combinada para poder filtrar las combinaciones product/cliente ya predichas
productos_con_prediccion['product_customer_id'] = productos_con_prediccion['product_id'].astype(str) + '_' + productos_con_prediccion['customer_id'].astype(str)
dataset_completo['product_customer_id'] = dataset_completo['product_id'].astype(str) + '_' + dataset_completo['customer_id'].astype(str)

# Filtrar por la dupla customer_id y product_id
df = dataset_completo[~dataset_completo['product_customer_id'].isin(productos_con_prediccion['product_customer_id'].values)]

# Eliminar la columna combinada si ya no es necesaria
df = df.drop(columns=['product_customer_id'])
dataset_completo = dataset_completo.drop(columns=['product_customer_id'])
productos_con_prediccion = productos_con_prediccion.drop(columns=['product_customer_id'])

df
# Out:
#          periodo  customer_id  product_id  plan_precios_cuidados
# 10753     201701        10395       20005                      0  \
# 10754     201701        10195       20005                      0
# 10755     201701        10225       20005                      0
# 10756     201701        10288       20005                      0
# 10757     201701        10158       20005                      0
# ...          ...          ...         ...                    ...
# 2292109   201912        10159       20014                      0
# 2292110   201912        10291       20014                      0
# 2292111   201912        10022       20014                      0
# 2292112   201912        10013       20014                      0
# 2292113   201912        10043       20014                      0
#
#          cust_request_qty  cust_request_tn        tn   cat1
# 10753                   1          0.08590   0.08590  FOODS  \
# 10754                   1          2.06170   2.06170  FOODS
# 10755                   1          0.42952   0.42952  FOODS
# 10756                   1          0.17181   0.17181  FOODS
# 10757                   1          0.04295   0.04295  FOODS
# ...                   ...              ...       ...    ...
# 2292109                 2          0.16380   0.16380     HC
# 2292110                 1          0.16380   0.16380     HC
# 2292111                 1          4.35708   4.35708     HC
# 2292112                 3         18.73872  18.73872     HC
# 2292113                 1          0.12012   0.12012     HC
#
#                         cat2            cat3  ... sku_size       descripcion
# 10753               ADEREZOS        Mayonesa  ...    120.0  Regular sin TACC  \
# 10754               ADEREZOS        Mayonesa  ...    120.0  Regular sin TACC
# 10755               ADEREZOS        Mayonesa  ...    120.0  Regular sin TACC
# 10756               ADEREZOS        Mayonesa  ...    120.0  Regular sin TACC
# 10757               ADEREZOS        Mayonesa  ...    120.0  Regular sin TACC
# ...                      ...             ...  ...      ...               ...
# 2292109  ROPA ACONDICIONADOR  ACONDICIONADOR  ...   3000.0          Sabor 13
# 2292110  ROPA ACONDICIONADOR  ACONDICIONADOR  ...   3000.0          Sabor 13
# 2292111  ROPA ACONDICIONADOR  ACONDICIONADOR  ...   3000.0          Sabor 13
# 2292112  ROPA ACONDICIONADOR  ACONDICIONADOR  ...   3000.0          Sabor 13
# 2292113  ROPA ACONDICIONADOR  ACONDICIONADOR  ...   3000.0          Sabor 13
#
#         mes  quarter  fin_quarter  edad_producto  ventas_cat1  ventas_cat2
# 10753     1        1            0              0      0.27734      0.24642  \
# 10754     1        1            0              0      8.22598      6.79992
# 10755     1        1            0              0      3.18760      2.16183
# 10756     1        1            0              0      0.91607      0.60803
# 10757     1        1            0              0      6.54173      4.12110
# ...      ..      ...          ...            ...          ...          ...
# 2292109  12        4            1             35      2.56273      0.57369
# 2292110  12        4            1             35      5.68662      0.81823
# 2292111  12        4            1             35    339.13673     19.79160
# 2292112  12        4            1             35    475.42938     38.30299
# 2292113  12        4            1             35     48.26345      5.08676
#
#          ventas_cat3  ventas_familia_producto
# 10753        0.24642                  0.24642
# 10754        5.12361                  4.95255
# 10755        1.87006                  1.76978
# 10756        0.52716                  0.17181
# 10757        3.11612                  1.27626
# ...              ...                      ...
# 2292109      0.41884                  0.18326
# 2292110      0.59983                  0.45569
# 2292111     18.85652                  9.26086
# 2292112     34.55525                 18.73872
# 2292113      5.03216                  2.57201
#
# [101970 rows x 21 columns]

# %%
#Encoding de columnas categoricas
''''
columnas_categoricas = ['cat1', 'cat2', 'cat3', 'brand']

dict_encoders = {}
for columna in columnas_categoricas:
    encoder = LabelEncoder()
    df[columna] = encoder.fit_transform(df[columna])
    dict_encoders[columna] = encoder

joblib.dump(dict_encoders, os.path.join(carpeta_exp,'label_encoder.pkl')) #Guardar el label encoder en un pickle

'''
###Por ahora eliminamos cat1, cat2, cat3, porque son iguales en todas las filas
df_producto_cliente_completo.drop(columns=['sku_size', 'descripcion', 'cust_request_qty', 'cust_request_tn','cat1', 'cat2', 'cat3', 'brand'], inplace = True)
df_producto_cliente_completo.set_index('Timestamp', inplace = True)

# %%
# Crear lags y rellenar NA
def crear_lags(df, lags):
    for lag in range(1, lags + 1):
        df[f'tn_lag_{lag}'] = df['tn'].shift(lag)
        df[f'tn_lag_{lag}'].bfill(inplace=True) # Usar backfill para llenar los valores NaN
        df[f'ventas_cat1_lag_{lag}'] = df['ventas_cat1'].shift(lag)
        df[f'ventas_cat1_lag_{lag}'].bfill(inplace=True) # Usar backfill para llenar los valores NaN
        df[f'ventas_cat2_lag_{lag}'] = df['ventas_cat2'].shift(lag)
        df[f'ventas_cat2_lag_{lag}'].bfill(inplace=True) # Usar backfill para llenar los valores NaN
        df[f'ventas_cat3_lag_{lag}'] = df['ventas_cat3'].shift(lag)
        df[f'ventas_cat3_lag_{lag}'].bfill(inplace=True) # Usar backfill para llenar los valores NaN
        df[f'ventas_familia_producto_lag_{lag}'] = df['ventas_familia_producto'].shift(lag)
        df[f'ventas_familia_producto_lag_{lag}'].bfill(inplace=True) # Usar backfill para llenar los valores NaN
    return df

def crear_dataset_supervisado(array, input_length, output_length):
    # Inicialización
    X, Y = [], []    # Listados que contendrán los datos de entrada y salida del modelo
    shape = array.shape
    if len(shape)==1: # Si tenemos sólo una serie (univariado)
        fils, cols = array.shape[0], 1
        array = array.reshape(fils,cols)
    else: # Multivariado
        fils, cols = array.shape
    # Generar los arreglos (utilizando ventanas deslizantes de longitud input_length)
    for i in range(fils-input_length-output_length + 1):
        X.append(array[i:i+input_length,0:cols])
        Y.append(array[i+input_length:i+input_length+output_length,-1].reshape(output_length,1))

    # Convertir listas a arreglos de NumPy
    X = np.array(X)
    Y = np.array(Y)

    return X, Y

# Definir función para crear y entrenar el modelo
def crear_modelo(ventana_input, ventana_output, lstm_units=[64, 32], dropout_rate=0.5, recurrent_dropout=0.25):
    model = Sequential()
    model.add(LSTM(lstm_units[0], return_sequences=True, input_shape=(ventana_input, X.shape[2]), recurrent_dropout=recurrent_dropout))
    for units in lstm_units[1:]:
        model.add(LSTM(units, recurrent_dropout=recurrent_dropout))
    model.add(Dropout(dropout_rate))
    model.add(Dense(ventana_output))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
#Cargar scalers si ya existen creados
if os.path.exists(os.path.join(carpeta_exp, 'scalers.pkl')):
    # Si existe archivo, leerlo
    scalers_dict = joblib.load(os.path.join(carpeta_exp, 'scalers.pkl'))
else:
    scalers_dict = {}


EPOCHS = 100
BATCH_SIZE = 64

#Cantidad de productos pendientes de predecir
cant_productos_pendientes = len(df['product_id'].unique())

# Entrenar y predecir
i = 0
for producto in df_producto_cliente_completo['product_id'].unique():
    i += 1
    ventas_mes_por_producto = df_producto_cliente_completo[df_producto_cliente_completo['product_id'] == producto].copy()
    for cliente in ventas_mes_por_producto['customer_id'].unique():
        print(f'Entrenando cliente: {cliente}, producto: {producto}')
        ventas_mes_por_producto_cliente = ventas_mes_por_producto[ventas_mes_por_producto['customer_id'] == cliente].copy()
        ventas_mes_por_producto_cliente.drop(columns=['product_id', 'customer_id'], inplace=True)
        

        lista_scalers = []
        for columna in ['tn', 'edad_producto', 'ventas_cat1', 'ventas_cat2', 'ventas_cat3', 'ventas_familia_producto']:
            scaler = RobustScaler()
            ventas_mes_por_producto_cliente[columna] = scaler.fit_transform(ventas_mes_por_producto_cliente[columna].values.reshape(-1,1))
            lista_scalers.append(scaler)
        scalers_dict[f'{producto}-{cliente}'] = lista_scalers

        ventas_mes_por_producto_cliente = crear_lags(ventas_mes_por_producto_cliente, lags)
        X, Y = crear_dataset_supervisado(np.array(ventas_mes_por_producto_cliente), ventana_input, ventana_output)

        
        model = crear_modelo(ventana_input, ventana_output)
        model.fit(X, Y, epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=1)
        y_pred_s = model.predict(X[-1].reshape(1,X.shape[1],X.shape[2]), verbose=0)
        y_pred = scaler.inverse_transform(y_pred_s)
        prediccion_mes_2 = y_pred.flatten()[1]
        nueva_prediccion = pd.DataFrame({'product_id': [producto], 'customer_id': [cliente], 'prediccion': [prediccion_mes_2]})
        productos_con_prediccion = pd.concat([productos_con_prediccion, nueva_prediccion], axis = 0)
        productos_con_prediccion.to_csv(os.path.join(carpeta_exp,nombre_archivo_log), index = False)
# Out:
# Entrenando cliente: 10063, producto: 20007
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.9219
# Epoch 2/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9191
# Epoch 3/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0703
# Epoch 4/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9134
# Epoch 5/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0344
# Epoch 6/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.9074
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8434
# Epoch 8/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9427
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.1041
# Epoch 10/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0960
# Epoch 11/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8804
# Epoch 12/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9658
# Epoch 13/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9838
# Epoch 14/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9006
# Epoch 15/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9449
# Epoch 16/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9429
# Epoch 17/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9621
# Epoch 18/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9197
# Epoch 19/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1.0198
# Epoch 20/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8985
# Epoch 21/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9320
# Epoch 22/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8850
# Epoch 23/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9247
# Epoch 24/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8809
# Epoch 25/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9041
# Epoch 26/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.8924
# Epoch 27/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.8164
# Epoch 28/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8328
# Epoch 29/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8733
# Epoch 30/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8726
# Epoch 31/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7673
# Epoch 32/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.8525
# Epoch 33/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.9023
# Epoch 34/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8297
# Epoch 35/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8709
# Epoch 36/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8353
# Epoch 37/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7760
# Epoch 38/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8562
# Epoch 39/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8031
# Epoch 40/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8279
# Epoch 41/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9026
# Epoch 42/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7888
# Epoch 43/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8010
# Epoch 44/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8664
# Epoch 45/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7546
# Epoch 46/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8593
# Epoch 47/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8331
# Epoch 48/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7589
# Epoch 49/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7955
# Epoch 50/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7485
# Epoch 51/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.8276
# Epoch 52/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6846
# Epoch 53/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7202
# Epoch 54/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7768
# Epoch 55/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6908
# Epoch 56/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7876
# Epoch 57/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7143
# Epoch 58/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7067
# Epoch 59/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7240
# Epoch 60/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7356
# Epoch 61/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.7257
# Epoch 62/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5945
# Epoch 63/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6808
# Epoch 64/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6238
# Epoch 65/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6071
# Epoch 66/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6218
# Epoch 67/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5970
# Epoch 68/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5510
# Epoch 69/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5839
# Epoch 70/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5769
# Epoch 71/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5877
# Epoch 72/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5226
# Epoch 73/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6319
# Epoch 74/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4603
# Epoch 75/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6448
# Epoch 76/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4688
# Epoch 77/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4575
# Epoch 78/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4656
# Epoch 79/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4548
# Epoch 80/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3303
# Epoch 81/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4310
# Epoch 82/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3304
# Epoch 83/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4310
# Epoch 84/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4726
# Epoch 85/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3507
# Epoch 86/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3340
# Epoch 87/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3656
# Epoch 88/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3276
# Epoch 89/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3831
# Epoch 90/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2909
# Epoch 91/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3190
# Epoch 92/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3545
# Epoch 93/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3123
# Epoch 94/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3806
# Epoch 95/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2228
# Epoch 96/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2388
# Epoch 97/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3311
# Epoch 98/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3271
# Epoch 99/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2295
# Epoch 100/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2852
# Entrenando cliente: 10046, producto: 20007
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.9955
# Epoch 2/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6800
# Epoch 3/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6236
# Epoch 4/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5923
# Epoch 5/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4173
# Epoch 6/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5844
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5424
# Epoch 8/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5475
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5547
# Epoch 10/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5985
# Epoch 11/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4715
# Epoch 12/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4264
# Epoch 13/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5107
# Epoch 14/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4492
# Epoch 15/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4432
# Epoch 16/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4613
# Epoch 17/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3678
# Epoch 18/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4086
# Epoch 19/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4829
# Epoch 20/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4706
# Epoch 21/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4933
# Epoch 22/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4280
# Epoch 23/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4051
# Epoch 24/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4312
# Epoch 25/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4124
# Epoch 26/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4599
# Epoch 27/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3304
# Epoch 28/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3637
# Epoch 29/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4037
# Epoch 30/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3901
# Epoch 31/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3808
# Epoch 32/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4153
# Epoch 33/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4132
# Epoch 34/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4018
# Epoch 35/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3662
# Epoch 36/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3254
# Epoch 37/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3353
# Epoch 38/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4110
# Epoch 39/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3862
# Epoch 40/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3731
# Epoch 41/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3422
# Epoch 42/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3409
# Epoch 43/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3380
# Epoch 44/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3246
# Epoch 45/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3615
# Epoch 46/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3453
# Epoch 47/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3881
# Epoch 48/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3502
# Epoch 49/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3211
# Epoch 50/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2714
# Epoch 51/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3382
# Epoch 52/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3313
# Epoch 53/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3866
# Epoch 54/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3318
# Epoch 55/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3182
# Epoch 56/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2939
# Epoch 57/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3698
# Epoch 58/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3360
# Epoch 59/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2799
# Epoch 60/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3319
# Epoch 61/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3224
# Epoch 62/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3605
# Epoch 63/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3481
# Epoch 64/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2961
# Epoch 65/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3037
# Epoch 66/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3115
# Epoch 67/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2635
# Epoch 68/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3046
# Epoch 69/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2654
# Epoch 70/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3218
# Epoch 71/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3168
# Epoch 72/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2558
# Epoch 73/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2918
# Epoch 74/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2701
# Epoch 75/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2879
# Epoch 76/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2961
# Epoch 77/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2459
# Epoch 78/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2901
# Epoch 79/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2625
# Epoch 80/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2544
# Epoch 81/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2334
# Epoch 82/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3153
# Epoch 83/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2789
# Epoch 84/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2399
# Epoch 85/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3132
# Epoch 86/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2372
# Epoch 87/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2862
# Epoch 88/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2417
# Epoch 89/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2413
# Epoch 90/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2654
# Epoch 91/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2305
# Epoch 92/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1974
# Epoch 93/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.1986
# Epoch 94/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2627
# Epoch 95/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2679
# Epoch 96/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2088
# Epoch 97/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2110
# Epoch 98/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1953
# Epoch 99/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2804
# Epoch 100/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.1954
# Entrenando cliente: 10027, producto: 20007
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.7349
# Epoch 2/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4830
# Epoch 3/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.6293
# Epoch 4/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6052
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5818
# Epoch 6/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4768
# Epoch 7/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4993
# Epoch 8/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5379
# Epoch 9/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4009
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5331
# Epoch 11/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5171
# Epoch 12/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5332
# Epoch 13/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.5035
# Epoch 14/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4378
# Epoch 15/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4567
# Epoch 16/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4335
# Epoch 17/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5028
# Epoch 18/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4959
# Epoch 19/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4607
# Epoch 20/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4541
# Epoch 21/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4049
# Epoch 22/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4918
# Epoch 23/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3976
# Epoch 24/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5039
# Epoch 25/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4501
# Epoch 26/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4554
# Epoch 27/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4526
# Epoch 28/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4306
# Epoch 29/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4271
# Epoch 30/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4201
# Epoch 31/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4251
# Epoch 32/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4230
# Epoch 33/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3853
# Epoch 34/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4229
# Epoch 35/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3827
# Epoch 36/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4137
# Epoch 37/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3955
# Epoch 38/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4164
# Epoch 39/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3934
# Epoch 40/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4212
# Epoch 41/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4352
# Epoch 42/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4144
# Epoch 43/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4405
# Epoch 44/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3827
# Epoch 45/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3839
# Epoch 46/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3964
# Epoch 47/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4113
# Epoch 48/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4347
# Epoch 49/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3843
# Epoch 50/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3817
# Epoch 51/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3768
# Epoch 52/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4065
# Epoch 53/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4253
# Epoch 54/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3612
# Epoch 55/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3570
# Epoch 56/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3899
# Epoch 57/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3909
# Epoch 58/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3923
# Epoch 59/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4223
# Epoch 60/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3995
# Epoch 61/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3874
# Epoch 62/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3335
# Epoch 63/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3874
# Epoch 64/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3591
# Epoch 65/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3311
# Epoch 66/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3614
# Epoch 67/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3594
# Epoch 68/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3587
# Epoch 69/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3644
# Epoch 70/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3477
# Epoch 71/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3786
# Epoch 72/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3383
# Epoch 73/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3038
# Epoch 74/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3539
# Epoch 75/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3614
# Epoch 76/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3573
# Epoch 77/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3125
# Epoch 78/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3752
# Epoch 79/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3166
# Epoch 80/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3882
# Epoch 81/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2712
# Epoch 82/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3242
# Epoch 83/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3163
# Epoch 84/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2912
# Epoch 85/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3310
# Epoch 86/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3202
# Epoch 87/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3088
# Epoch 88/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3374
# Epoch 89/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2532
# Epoch 90/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3106
# Epoch 91/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3511
# Epoch 92/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3111
# Epoch 93/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3139
# Epoch 94/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3073
# Epoch 95/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3033
# Epoch 96/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2683
# Epoch 97/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.3107
# Epoch 98/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2730
# Epoch 99/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.2898
# Epoch 100/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.2714
# Entrenando cliente: 10045, producto: 20007
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.7092
# Epoch 2/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6394
# Epoch 3/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4904
# Epoch 4/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3838
# Epoch 5/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3876
# Epoch 6/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3536
# Epoch 7/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3696
# Epoch 8/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.4556
# Epoch 9/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3867
# Epoch 10/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4572
# Epoch 11/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4409
# Epoch 12/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4351
# Epoch 13/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3736
# Epoch 14/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3403
# Epoch 15/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3389
# Epoch 16/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2847
# Epoch 17/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2672
# Epoch 18/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3528
# Epoch 19/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3286
# Epoch 20/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2747
# Epoch 21/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2892
# Epoch 22/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2929
# Epoch 23/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2809
# Epoch 24/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3327
# Epoch 25/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2805
# Epoch 26/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2864
# Epoch 27/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3136
# Epoch 28/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2928
# Epoch 29/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2567
# Epoch 30/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3052
# Epoch 31/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2399
# Epoch 32/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2598
# Epoch 33/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2415
# Epoch 34/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2854
# Epoch 35/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2573
# Epoch 36/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2919
# Epoch 37/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2719
# Epoch 38/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2360
# Epoch 39/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2682
# Epoch 40/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2293
# Epoch 41/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2600
# Epoch 42/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2572
# Epoch 43/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2413
# Epoch 44/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2324
# Epoch 45/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2293
# Epoch 46/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2163
# Epoch 47/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2288
# Epoch 48/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2477
# Epoch 49/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2288
# Epoch 50/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2434
# Epoch 51/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2342
# Epoch 52/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2033
# Epoch 53/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2333
# Epoch 54/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.2346
# Epoch 55/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1890
# Epoch 56/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2485
# Epoch 57/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2259
# Epoch 58/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2116
# Epoch 59/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2063
# Epoch 60/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2350
# Epoch 61/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2006
# Epoch 62/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2319
# Epoch 63/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2302
# Epoch 64/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2282
# Epoch 65/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2369
# Epoch 66/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.2020
# Epoch 67/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1859
# Epoch 68/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2050
# Epoch 69/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2092
# Epoch 70/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2461
# Epoch 71/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1785
# Epoch 72/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2081
# Epoch 73/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2050
# Epoch 74/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2072
# Epoch 75/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1861
# Epoch 76/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2029
# Epoch 77/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2144
# Epoch 78/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1895
# Epoch 79/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2152
# Epoch 80/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2163
# Epoch 81/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1894
# Epoch 82/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2104
# Epoch 83/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1627
# Epoch 84/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1964
# Epoch 85/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1813
# Epoch 86/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.2082
# Epoch 87/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1869
# Epoch 88/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1943
# Epoch 89/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2128
# Epoch 90/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.2177
# Epoch 91/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1854
# Epoch 92/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1958
# Epoch 93/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1589
# Epoch 94/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1739
# Epoch 95/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1632
# Epoch 96/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1797
# Epoch 97/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1526
# Epoch 98/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1749
# Epoch 99/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1523
# Epoch 100/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1825
# Entrenando cliente: 10488, producto: 20007
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 10.9200
# Epoch 2/100
# 1/1 [==============================] - 0s 10ms/step - loss: 10.5042
# Epoch 3/100
# 1/1 [==============================] - 0s 11ms/step - loss: 10.7004
# Epoch 4/100
# 1/1 [==============================] - 0s 11ms/step - loss: 10.0552
# Epoch 5/100
# 1/1 [==============================] - 0s 11ms/step - loss: 9.6740
# Epoch 6/100
# 1/1 [==============================] - 0s 11ms/step - loss: 9.9756
# Epoch 7/100
# 1/1 [==============================] - 0s 10ms/step - loss: 9.8350
# Epoch 8/100
# 1/1 [==============================] - 0s 10ms/step - loss: 9.6898
# Epoch 9/100
# 1/1 [==============================] - 0s 10ms/step - loss: 9.0900
# Epoch 10/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.7513
# Epoch 11/100
# 1/1 [==============================] - 0s 10ms/step - loss: 9.4906
# Epoch 12/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.7934
# Epoch 13/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.5490
# Epoch 14/100
# 1/1 [==============================] - 0s 10ms/step - loss: 9.4143
# Epoch 15/100
# 1/1 [==============================] - 0s 11ms/step - loss: 8.6336
# Epoch 16/100
# 1/1 [==============================] - 0s 11ms/step - loss: 9.4572
# Epoch 17/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.5514
# Epoch 18/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.2269
# Epoch 19/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.4947
# Epoch 20/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.0250
# Epoch 21/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.0136
# Epoch 22/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.2466
# Epoch 23/100
# 1/1 [==============================] - 0s 11ms/step - loss: 8.1549
# Epoch 24/100
# 1/1 [==============================] - 0s 10ms/step - loss: 7.6666
# Epoch 25/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7.5313
# Epoch 26/100
# 1/1 [==============================] - 0s 12ms/step - loss: 8.5986
# Epoch 27/100
# 1/1 [==============================] - 0s 12ms/step - loss: 7.6298
# Epoch 28/100
# 1/1 [==============================] - 0s 12ms/step - loss: 7.5680
# Epoch 29/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7.3049
# Epoch 30/100
# 1/1 [==============================] - 0s 10ms/step - loss: 7.4689
# Epoch 31/100
# 1/1 [==============================] - 0s 10ms/step - loss: 7.0703
# Epoch 32/100
# 1/1 [==============================] - 0s 11ms/step - loss: 6.7165
# Epoch 33/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7.3116
# Epoch 34/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.4126
# Epoch 35/100
# 1/1 [==============================] - 0s 9ms/step - loss: 7.1305
# Epoch 36/100
# 1/1 [==============================] - 0s 11ms/step - loss: 5.7559
# Epoch 37/100
# 1/1 [==============================] - 0s 10ms/step - loss: 7.1472
# Epoch 38/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7.0356
# Epoch 39/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.4205
# Epoch 40/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.9675
# Epoch 41/100
# 1/1 [==============================] - 0s 10ms/step - loss: 7.2347
# Epoch 42/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.0013
# Epoch 43/100
# 1/1 [==============================] - 0s 11ms/step - loss: 5.8676
# Epoch 44/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.2007
# Epoch 45/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.4041
# Epoch 46/100
# 1/1 [==============================] - 0s 11ms/step - loss: 7.2685
# Epoch 47/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.1877
# Epoch 48/100
# 1/1 [==============================] - 0s 10ms/step - loss: 7.0869
# Epoch 49/100
# 1/1 [==============================] - 0s 11ms/step - loss: 6.5083
# Epoch 50/100
# 1/1 [==============================] - 0s 10ms/step - loss: 5.9309
# Epoch 51/100
# 1/1 [==============================] - 0s 16ms/step - loss: 5.9337
# Epoch 52/100
# 1/1 [==============================] - 0s 12ms/step - loss: 5.5266
# Epoch 53/100
# 1/1 [==============================] - ETA: 0s - loss: 5.4848
